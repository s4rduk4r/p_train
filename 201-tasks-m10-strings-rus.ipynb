# %% [markdown]
# # Модуль 10 Строки
#
# ## Задача 137.
#
# Дана следующая кодовая строка, вставьте правильный негативный индекс на строке 3 для получения последнего символа в строке.
#
# ```python
# my_string = "In 2010, someone paid 10k Bitcoin for two pizzas."
# print(my_string[])
# ```

# %% [markdown]
# ## Задача 138.
#
# Дана следующая кодовая строка, вставьте правильный положительный индекс на строке 3 для возврата запятой из строки.
#
# ```python
# my_string = "In 2010, someone paid 10k Bitcoin for two pizzas."
# print(my_string[])
# ```

# %% [markdown]
# ## Задача 139.
#
# Дана следующая кодовая строка, вставьте правильный негативный индекс на строке 3 для возврата символа w из строки.
#
# ```python
# my_string = "In 2010, someone paid 10k Bitcoin for two pizzas."
# print(my_string[])
# ```

# %% [markdown]
# ## Задача 140.
#
# Дана следующая кодовая строка, вставьте правильный метод на строке 3 для возврата индекса символа B в строке.
#
# ```python
# my_string = "In 2010, someone paid 10k Bitcoin for two pizzas."
# print(my_string.)
# ```

# %% [markdown]
# ## Задача 141.
#
# Дана следующая кодовая строка, вставьте правильный метод на строке 3 для возврата количества повторений буквы o в строке.
#
# ```python
# my_string = "In 2010, someone paid 10k Bitcoin for two pizzas."
# print(my_string.)
# ```

# %% [markdown]
# ## Задача 142.
#
# Дана следующая кодовая строка, вставьте правильный метод на строке 3 для преобразования всех букв в строку в верхний регистр.
#
# ```python
# my_string = "In 2010, someone paid 10k Bitcoin for two pizzas."
# print(my_string.)
# ```

# %% [markdown]
# ## Задача 143.
#
# Дана следующая кодовая строка, вставьте правильный метод на строке 3 для получения индекса, с которого начинается подстрока Bitcoin.
#
# my_string = "In 2010, someone paid 10k Bitcoin for two pizzas."
# print(my_string.)
