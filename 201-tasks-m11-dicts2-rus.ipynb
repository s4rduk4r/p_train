# %% [markdown]
# # Модуль 11 Словарь
#
# ## Задача 144
#
# Создайте функцию get_name, которая возвращает значение ключа name, если такого ключа нет, то функция должна вернуть строку unknown name.
#
# ```python
# def get_name(dictionary: dict) -> str:
# # TODO
# arr = [
# 	{
# 		'name': 'John',
# 		'age': 25
# 	},
# 	{
# 		'age': 20
# 	},
# 	{
# 		'name': 'Tom',
# 		'age': 38
# 	},
# 	{}
# ]
# ```

# %% [markdown]
# ## Задача 145
#
# Создайте функцию get_name, которая возвращает значение ключа name, если такого ключа нет, то функция должна вернуть строку unknown name.
#
# ```python
# def get_name(dictionary: dict) -> str:
# # TODO
# arr = [
# 	{
# 		'name': 'John',
# 		'age': 25
# 	},
# 	{
# 		'age': 20
# 	},
# 	{
# 		'name': 'Tom',
# 		'age': 38
# 	},
# 	{}
# ]
# ```

# %% [markdown]
# ## Задача 146
#
# Отсортируйте список словарей arr по значению ключа age. Отсортированный список сохраните в переменную sorted_arr.
# Ожидаемый результат:
# [{'name': 'Alice', 'age': 20}, {'name': 'John', 'age': 25}, {'name': 'Tom', 'age': 38}]
#
# ```python
# arr = [
#     {
#         'name': 'John',
#         'age': 25
#     },
#     {
#         'name': 'Alice',
#         'age': 20
#     },
#     {
#         'name': 'Tom',
#         'age': 38
#     }
# ]
# sorted_arr =
# ```

# %% [markdown]
# ## Задача 147
#
# Преобразуйте два списка в словарь. Список keys хранит ключи словаря, а список values их значения.
# Ожидаемый результат:
# {'name': 'john', 'age': 25, 'grade': 'B'}
#
# ```python
# keys = ['name', 'age', 'grade']
# values = ['John', 25, 'B']
# dictionary =
# ```

# %% [markdown]
# ## Задача 148
#
# Создайте список из ключей словаря. Результат сохраните в переменную arr.
# Ожидаемый результат:
# ['name', 'age', 'grade']
#
# ```python
# dictionary = {
#     'name': 'John',
#     'age': 25,
#     'grade': 'B',
# }
# arr =
# ```

# %% [markdown]
# ## Задача 149
#
# Объедините два словаря dict_1 и dict_2. Результат сохраните в новом словаре new_dict.
# Ожидаемый результат:
# {'name': 'Anna', 'age': 20, 'weight': 55, 'height': 170}
#
# ```python
# dict_1 = {'name': 'Anna', 'age': 20}
# dict_2 = {'weight': 55, 'height': 170}
# new_dict =
# ```

# %% [markdown]
# ## Задача 150
#
# Отсортируйте словарь по ключам в порядке возрастания.
# Ожидаемый результат:
# {'Alice': 10, 'Anna': 20, 'Clinton': 18, 'Mark': 15}
#
# ```python
# dictionary = {'Anna': 20, 'Mark': 15, 'Clinton': 18, 'Alice': 10}
# dictionary =
# ```

# %% [markdown]
# ## Задача 151
#
# Добавьте ключ name со значением Mark к словарю.
# Ожидаемый результат:
# {'weight': 55, 'height': 170, 'name': 'Mark'}
#
# ```python
# dictionary = {'weight': 55, 'height': 170}
# ```

# %% [markdown]
# ## Задача 152
#
# Преобразуйте словарь в список кортежей. Первым элементом каждого кортежа должен быть ключ словаря, вторым - его значение. Сохраните результат в переменной arr_of_tuples.
# Ожидаемый результат:
# [('name', 'Anna'), ('age', 20), ('weight', 55), ('height', 170)]
#
# ```python
# dictionary = {'name': 'Anna', 'age': 20, 'weight': 55, 'height': 170}
# arr_of_tuples =
# ```

# %% [markdown]
# ## Задача 153
#
# Создайте функцию key_exists, которая проверяет наличие ключа name в данном словаре. Функция должна возвращать True или False.
#
# ```python
# def key_exists(dictionary: dict) -> bool:
#     arr_of_dicts = [
#         {
#             'name': 'John',
#             'age': 25
#         },
#         {
#             'color': 'blue'
#         },
#         {
#             'height': 175,
#             'weight': 55
#         }
#     ]
#     for dictionary in arr_of_dicts:
#         if key_exists(dictionary):
#             print(f'"name" key exists in {dictionary}')
#         else:
#             print(f'"name" key does not exist in {dictionary}')
# ```

# %% [markdown]
# ## Задача 154
#
# Удалите ключ name из словаря и сохраните его значение в переменную value.
# Ожидаемый результат:
# 'Anna'
#
# ```python
# dictionary = {'name': 'Anna', 'age': 20, 'weight': 55, 'height': 170}
# value =
# ```

# %% [markdown]
# ## Задача 155
#
# Создайте новый словарь new_dict с элементами данного словаря, кроме ключа age.
# Используйте генератор словарей.
# Ожидаемый результат:
# {'name': 'Anna', 'weight': 55, 'height': 170}
#
# ```python
# dictionary = {'name': 'Anna', 'age': 20, 'weight': 55, 'height': 170}
# new_dict =
# ```

# %% [markdown]
# ## Задача 156
#
# Получите ключ с максимальным значением в словаре. Сохраните результат в переменной key.
# Ожидаемый результат:
# ‘Anna'
#
# ```python
# dictionary = {'Anna': 20, 'Mark': 15, 'Clinton': 18, 'Alice': 10}
# key =
# ```

# %% [markdown]
# ## Задача 157
#
# Получите минимальное значение из словаря. Сохраните результат в переменной value.
# Ожидаемый результат:
# 10
#
# ```python
# dictionary = {'Anna': 20, 'Mark': 15, 'Clinton': 18, 'Alice': 10}
# value =
# ```

# %% [markdown]
# ## Задача 158
#
# Получите имя с минимальным значением в ключе age. Сохраните результат в переменной value.
# Ожидаемый результат:
# 'Alice'
#
# ```python
# arr_of_dicts = [
#     {
#         'name': 'John',
#         'age': 26
#     },
#     {
#         'name': 'Anna',
#         'age': 28
#     },
#     {
#         'name': 'Alice',
#         'age': 25
#     }
# ]
# value =
# ```

# %% [markdown]
# ## Задача 159
#
# Создайте копию словаря и сохраните ее в переменной new_dictionary (shallow copy).
#
# ```python
# dictionary = {'name': 'Anna', 'age': 20}
# new_dictionary =
# ```

# %% [markdown]
# ## Задача 160
#
# Создайте глубокую копию (deep copy) словаря и сохраните её в переменной new_dictionary.
#
# ```python
# dictionary = {'name': 'Anna', 'age': 20, 'skills': {'english': 'perfect', 'python': 'very good'}}
# new_dictionary =
# ```

# %% [markdown]
# ## Задача 161
#
# Получите значения словаря в виде списка. Сохраните результат в переменной names.
# Ожидаемый результат:
# ['Anna', 'Mark', 'Clinton', 'Alice']
#
# ```python
# dictionary = {'Anna': 20, 'Mark': 15, 'Clinton': 18, 'Alice': 10}
# names =
# ```

# %% [markdown]
# ## Задача 162
#
# Переверните пары ключ-значение словаря.
# Ожидаемый результат:
# {20: 'Anna', 15: 'Mark', 18: 'Clinton', 10: 'Alice'}
#
# ```python
# dictionary = {'Anna': 20, 'Mark': 15, 'Clinton': 18, 'Alice': 10}
# dictionary =
# ```

# %% [markdown]
# ## Задача 163
#
# Подсчитайте количество вхождений слова в строку sentence. Сохраните результат в словаре words. Каждое слово должно быть ключом словаря, а его значение - число вхождений данного слова в переменной sentence. Элементы строки исключают пробелы, точки и восклицательные знаки.
# Ожидаемый результат:
# {'I': 2, 'am': 1, 'learning': 1, 'Python': 3, 'love': 1, 'is': 1, 'the': 1, 'future': 1}
#
# ```python
# sentence = 'I am learning Python. I love Python. Python is the future!'
# words =
# ```

# %% [markdown]
# ## Задача 164
#
# Объедините два словаря dict_1 и dict_2. При совпадении ключей суммируйте значения. Сохраните результат в словаре combined_dict.
# Ожидаемый результат:
# {'a': 6, 'b': 5, 'c': 4}
#
# ```python
# dict_1 = {'a': 1, 'b': 2}
# dict_2 = {'a': 5, 'b': 3, 'c': 4}
# combined_dict =
# ```

# %% [markdown]
# ## Задача 165
#
# Создайте список словарей arr_of_dicts, где каждый словарь будет иметь две ключи: id и name. Значение для ключа id начинается с 1 и увеличивается на единицу в каждом следующем словаре. Значение для ключа name соответствует элементам списка names.
# Ожидаемый результат:
# [{'id': 1, 'name': 'Alice'}, {'id': 2, 'name': 'Tom'}, {'id': 3, 'name': 'John'}, {'id': 4, 'name': 'Sara'}]
#
# ```python
# names = ['Alice', 'Tom', 'John', 'Sara']
# arr_of_dicts =
# ```

# %% [markdown]
# ## Задача 166
#
# Создайте словарь, где значения будут строкой "Be happy!". Элементы массива будут ключами этого словаря.
# Ожидаемый результат:
# {50: 'Be happy!', 51: 'Be happy!', 52: 'Be happy!', 53: 'Be happy!', 54: 'Be happy!'}
#
# ```python
# arr = range(50, 55)
# dictionary =
# ```
