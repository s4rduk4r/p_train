# %% [markdown]
# # Модуль 12 Списки
#
# ## Задача 167
#
# Измените значение последнего элемента в списке `arr` на 0.
#
# Ожидаемый результат: \[1, 2, 0\]
#
# ```python
# arr = [1, 2, 3]
# arr =
# ```

# %% [markdown]
# ## Задача 168
#
# Создайте новый список `new_arr`, который содержит только последние два элемента списка `arr`.
#
# Ожидаемый результат: \[8, 9\]
#
# ```python
# arr = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# new_arr =
# ```

# %% [markdown]
# ## Задача 169
#
# Создайте новый список `new_arr`, который содержит только первые пять элементов списка `arr`.
#
# Ожидаемый результат: \[1, 2, 3, 4, 5\]
#
# ```python
# arr = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# new_arr =
# ```

# %% [markdown]
# ## Задача 170
#
# Создайте новый список `new_arr`, который содержит только четвертый, пятый и шестой элементы списка `arr`.
#
# Ожидаемый результат: \[4, 5, 6\]
#
# ```python
# arr = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# new_arr =
# ```

# %% [markdown]
# ## Задача 171
#
# Создайте новый список `new_arr`, который содержит только нечетные элементы списка `arr`.
#
# Ожидаемый результат: \[1, 3, 5, 7, 9\]
#
# ```python
# arr = \[1, 2, 3, 4, 5, 6, 7, 8, 9\]
# new_arr =
# ```

# %% [markdown]
# ## Задача 172
#
# Отсортируйте элементы в обратном порядке в списке arr и сохраните результат в переменной `new_arr`.
#
# Ожидаемый результат: \[2, 7, 7, 6, 5, 7, 3, 8, 1\]
#
# ```python
# arr = [1, 8, 3, 7, 5, 6, 7, 7, 2]
# new_arr =
# ```

# %% [markdown]
# ## Задача 173
#
# Создайте функцию `is_list_empty`, которая проверяет, является ли переданный ей список пустым. Если список пуст, функция должна вернуть `True`, иначе `False`.
#
# ```python
# def is_list_empty(arr: list) -> bool:
#     # TODO
# arrays = [[1, 2, 3], ['item'], []]
# for arr in arrays:
#     if is_list_empty(arr):
#         print(f'{arr} is a empty list')
#     else:
#         print(f'{arr} contains elements')
# ```

# %% [markdown]
# ## Задача 174
#
# Создайте новый список `new_arr`, который содержит элементы из двух списков. В начале должны быть элементы из списка `arr_1`, затем элементы из списка `arr_2`.
#
# Ожидаемый результат: [1, 2, 3, 4, 5]
#
# ```python
# arr_1 = [1, 2]
# arr_2 = [3, 4, 5]
# new_arr =
# ```

# %% [markdown]
# ## Задача 175
#
# Добавьте все элементы из списка `arr_1` к списку `arr_2`.
#
# Ожидаемый результат: \[1, 2, 3, 4\]
#
# ```python
# arr_1 = [3, 4]
# arr_2 = [1, 2]
# ```

# %% [markdown]
# ## Задача 176
#
# Создайте "поверхностную" копию списка `arr` и сохраните её в переменной `new_arr`.
#
# ```python
# arr = [1, 2]
# new_arr =
# ```

# %% [markdown]
# ## Задача 177
#
# Создайте глубокую копию списка `arr` и сохраните её в переменной `new_arr`.
#
# ```python
# arr = [1, [2]]
# new_arr =
# ```

# %% [markdown]
# ## Задача 178
#
# Получите количество элементов в списке `arr`. Сохраните результат в переменной `arr_length`.
#
# Ожидаемый результат: 4
#
# ```python
# arr = [1, 2, 3, 4]
# arr_length =
# ```

# %% [markdown]
# ## Задача 179
#
# Подсчитайте количество вхождений цифры 2 в списке `arr`. Сохраните результат в переменной `count`.
#
# Ожидаемый результат: 3
#
# ```python
# arr = [1, 2, 3, 4, 2, 5, 5, 2]
# count =
# ```

# %% [markdown]
# ## Задача 180
#
# Удалите последний элемент из списка `arr` и сохраните его в переменной `last_item`.
#
# ```python
# arr = [1, 2, 3]
# last_item =
# ```

# %% [markdown]
# ## Задача 181
#
# Удалите элемент с значением `2` из списка `arr`.
#
# Ожидаемый результат: \[1, 3, 4\]
#
# ```python
# arr = [1, 2, 3, 4]
# ```

# %% [markdown]
# ## Задача 182
#
# Отсортируйте элементы списка `arr` в обратном порядке. Сохраните результат в переменной `new_arr`.
#
# Ожидаемый результат: \[9, 6, 4, 2\]
#
# ```python
# arr = \[2, 6, 4, 9\]
# new_arr =
# ```

# %% [markdown]
# ## Задача 183
#
# Создайте новый список `new_arr`, который содержит только уникальные элементы из списка `arr`.
#
# Ожидаемый результат: \[1, 2, 3, 4\]
#
# ```python
# arr = [4, 2, 1, 1, 3, 2, 1, 3, 4, 4, 4, 3]
# new_arr =
# ```

# %% [markdown]
# ## Задача 184
#
# Удалите элементы со значениями 1 и `3` из списка `arr`.
#
# Ожидаемый результат: \[4, 2, 2, 4, 4, 4\]
#
# ```python
# arr = [4, 2, 1, 1, 3, 2, 1, 3, 4, 4, 4, 3]
# arr =
# ```

# %% [markdown]
# ## Задача 185
#
# Создайте список разности с элементами из списка `arr_1`, которые отсутствуют в списке `arr_2`.
#
# Ожидаемый результат: \[1, 2\]
#
# ```python
# arr_1 = [1, 2, 3, 4]
# arr_2 = [3, 4, 6]
# difference =
# ```

# %% [markdown]
# ## Задача 186
#
# Преобразуйте список `arr` в строку. Элементы из списка должны быть разделены запятой `,` и пробелом. Сохраните результат в переменной `names`.
#
# Ожидаемый результат: `"Alice, Tom, John"`
#
# ```python
# arr = ['Alice', 'Tom', 'John']
# names =
# ```

# %% [markdown]
# ## Задача 187
#
# Удалите пустые строки из списка `arr`.
#
# Ожидаемый результат: \['Alice', 'Tom', 'John'\]
#
# ```python
# arr = ['Alice', '', 'Tom', 'John', '']
# arr =
# ```

# %% [markdown]
# ## Задача 188
#
# Найдите наименьшее число в списке `arr`. Сохраните результат в переменной `smallest_number`.
#
# Ожидаемый результат: -60
#
# ```python
# arr = \[104, -60, 0, 399, -30, -5\]
# smallest_number =
# ```

# %% [markdown]
# ## Задача 189
#
# Создайте функцию `are_elements_true`, которая проверяет, являются ли все элементы переданного ей списка `True`. Функция должна возвращать `True` или `False`.
#
# ```python
# def are_elements_true(arr: list) -> bool:
#     # TODO
#
# arrays = [[0, True, 1], [22, True], ['a', 'b', 4]]
# for arr in arrays:
#     if are_elements_true(arr):
#         print(f'All items in {arr} are "True"')
#     else:
#         print(f'Some items in {arr} are "False"')
# ```

# %% [markdown]
# ## Задача 190
#
# В списке чисел найдите все числа больше `25`. Сохраните результат в переменной `new_numbers`.
#
# Ожидаемый результат: \[88, 45, 98, 34, 55, 48\]
#
# ```python
# numbers = [88, 45, 4, 7, 98, 34, 21, 18, 14, 55, 48, 1]
# new_numbers =
# ```

# %% [markdown]
# ## Задача 191
#
# Найдите среднее арифметическое всех чисел в списке `arr` и округлите до двух знаков после запятой. Сохраните результат в переменной `mean`.
#
# Ожидаемый результат: 28.11
#
# ```python
# arr = [6, 4, 56, 34, 23, 78, 1, 34, 17]
# mean =
# ```

# %% [markdown]
# ## Задача 192
#
# Найдите дубликаты в списке `arr` и создайте список `duplicates` с ними.
#
# Ожидаемый результат: \[ 'a', 11, 4, 8\]
#
# ```python
# arr = ['a', 11, 14, 11, 'a', 'a', 'f', 4, 4, 'a', 6, 8, 8, 8]
# duplicates =
# ```

# %% [markdown]
# ## Задача 193
#
# Получите все индексы из списка `arr` для элементов, у которых значение больше `2`. Сохраните результат в переменной `indexes`.
#
# Ожидаемый результат: \[2, 5, 6, 9\]
#
# ```python
# arr = [5, 4, 2, 7, 6, 2, 2, 1, 1, 2]
# indexes =
# ```

# %% [markdown]
# ## Задача 194
#
# Создайте список `numbers`, содержащий только чётные числа из диапазона `16-76`.
#
# Ожидаемый результат:
# \[16, 18, 20, 22, 24, 26, 28, 30, 32, 34, 36, 38, 40, 42, 44, 46, 48, 50, 52, 54, 56, 58, 60, 62, 64, 66, 68, 70, 72, 74, 76\]
#
# ```python
# numbers = [16, 18, 20, 22, 24, 26, 28, 30, 32, 34, 36, 38, 40, 42, 44, 46, 48, 50, 52, 54, 56, 58, 60, 62, 64, 66, 68, 70, 72, 74, 76]
# numbers =
# ```

# %% [markdown]
# ## Задача 195
#
# Получите список значений из словаря `names_dict` и сохраните его в переменной `names`.
#
# Ожидаемый результат:
# \['Anna', 'Tom', 'Alice', 'Mark'\]
#
# ```python
# names_dict = [1: 'Anna', 2: 'Tom', 3: 'Alice', 4: 'Mark']
# names =
# ```

# %% [markdown]
# ## Задача 196
#
# Добавьте значение 10 ко всем элементам в списке `numbers`.
#
# Ожидаемый результат: \[15, 14, 17, 18, 32, 577\]
#
# ```python
# numbers = [5, 4, 7, 8, 22, 567]
# numbers =
# ```

# %% [markdown]
# ## Задача 197
#
# Создайте новый список new_arr, содержащий только уникальные элементы из нового списка arr, чтобы порядок элементов был таким же, как в исходном списке arr.
# Ожидаемый результат:
# \[4, 7, 15, 56, 6, 89, 111\]
#
# ```python
# arr = [4, 7, 15, 4, 4, 56, 6, 6, 89, 15, 111]
# ```

# %% [markdown]
# ## Задача 198
#
# Создайте плоский список из списка списков. Сохраните результат в переменной `merged_arr`.
#
# Ожидаемый результат: \[1, 2, 3, 4, 5, 6, 7, 8, 9\]
#
# ```python
# arr = [[1, 2], [3], [4, 5, 6, 7], [8, 9]]
# merged_arr =
# ```

# %% [markdown]
# ## Задача 199
#
# Отсортируйте список `arr` по возрастанию возраста объектов. Список должен быть отсортирован в обратном порядке.
#
# Ожидаемый результат:
# \[Дон - 37, Том - 34, Алиса - 28\]
#
# ```python
# class Person:
#     def __init__(self, name: str, age: int):
#         self.name = name
#         self.age = age
#
#     def __repr__(self):
#         return f'{self.name} - {self.age}'
#
# p1 = Person('Том', 34)
# p2 = Person('Алиса', 28)
# p3 = Person('Дон', 37)
#
# arr = [p1, p2, p3]
# arr =
# ```

# %% [markdown]
# ## Задача 200
#
# Вычислите сумму диагональных элементов двумерного массива. Например: \[[1, 8, 9], [1, 5, 6], [7, 6, 9]\] => сумма 1 + 5 + 9 => 15

# %% [markdown]
# ## Задача 201
#
# Возведите в квадрат каждый элемент списка.
#
# ```python
# aList = [1, 14, 23, 4, 15, 6, 27]
# ```
