# %% [markdown]
# # Модуль 2 Словари
#
# ## Задача 9
#
# Дан код ниже, используйте правильный код на третьей строке для возврата значения, связанного с ключом 4. Не используйте метод как решение этой задачи!
#
# ```python
# crypto = {1: "Bitcoin", 2: "Ethereum", 3: "Litecoin", 4: "Stellar", 5: "XRP"}
# value =
# print(value)
# ```

# %% [markdown]
# ## Задача 10
#
# Дан код ниже, используйте правильный код на третьей строке для возврата значения, связанного с ключом 4. В этот раз, используйте метод как решение этой задачи!
#
# ```python
# crypto = {1: "Bitcoin", 2: "Ethereum", 3: "Litecoin", 4: "Stellar", 5: "XRP"}
# value =
# print(value)
# ```

# %% [markdown]
# ## Задача 11
#
# Дан код ниже, используйте правильный код на третьей строке для обновления значения, связанного с ключом 4 до "Cardano".
#
# ```python
# crypto = {1: "Bitcoin", 2: "Ethereum", 3: "Litecoin", 4: "Stellar", 5: "XRP"}
# print(crypto[4])
# ```

# %% [markdown]
# ## Задача 12
#
# Дан код ниже, используйте правильный код на третьей строке для добавления новой пары ключ-значение в словарь: 6: "Monero"
#
# ```python
# crypto = {1: "Bitcoin", 2: "Ethereum", 3: "Litecoin", 4: "Stellar", 5: "XRP"}
# print(crypto[6])
# ```

# %% [markdown]
# ## Задача 13
#
# Дан код ниже, используйте правильный код на третьей строке для возврата числа пар ключ-значение в словаре.
#
# ```python
# crypto = {1: "Bitcoin", 2: "Ethereum", 3: "Litecoin", 4: "Stellar", 5: "XRP"}
# number =
# print(number)
# ```

# %% [markdown]
# ## Задача 14
#
# Дан код ниже, используйте правильный код на третьей строке для удаления пары ключ-значение, связанной с ключом 3. Не используйте метод как решение этой задачи!
#
# ```python
# crypto = {1: "Bitcoin", 2: "Ethereum", 3: "Litecoin", 4: "Stellar", 5: "XRP"}
# print(crypto)
# ```

# %% [markdown]
# ## Задача 15
#
# Дан код ниже, используйте правильный код на третьей строке для удаления пары ключ-значение, связанной с ключом 3. В этот раз, используйте метод как решение этой задачи!
#
# ```python
# crypto = {1: "Bitcoin", 2: "Ethereum", 3: "Litecoin", 4: "Stellar", 5: "XRP"}
# print(crypto)
# ```

# %% [markdown]
# ## Задача 16
#
# Дан код ниже, используйте правильный код на третьей строке для проверки того, является ли 7 ключом в словаре.
#
# ```python
# crypto = {1: "Bitcoin", 2: "Ethereum", 3: "Litecoin", 4: "Stellar", 5: "XRP"}
# check =
# print(check)
# ```

# %% [markdown]
# ## Задача 17
#
# Дан код ниже, используйте правильный метод на третьей строке для удаления всех элементов из словаря.
#
# ```python
# crypto = {1: "Bitcoin", 2: "Ethereum", 3: "Litecoin", 4: "Stellar", 5: "XRP"}
# crypto.
# print(crypto)
# ```

# %% [markdown]
# ## Задача 18
#
# Дан код ниже, используйте правильный код на третьей строке для получения списка кортежей, где каждый кортеж представляет пару ключ-значение в словаре.
#
# ```python
# crypto = {1: "Bitcoin", 2: "Ethereum", 3: "Litecoin", 4: "Stellar", 5: "XRP"}
# result =
# print(list(result))
# ```

# %% [markdown]
# ## Задача 19
#
# Дан код ниже, используйте правильную функцию на третьей строке для получения суммы всех ключей в словаре.
#
# ```python
# crypto = {1: "Bitcoin", 2: "Ethereum", 3: "Litecoin", 4: "Stellar", 5: "XRP"}
# add =
# print(add)
# ```

# %% [markdown]
# ## Задача 20
#
# Дан код ниже, используйте правильный метод на третьей строке для получения списка всех значений в словаре.
#
# ```python
# crypto = {1: "Bitcoin", 2: "Ethereum", 3: "Litecoin", 4: "Stellar", 5: "XRP"}
# val =
# print(list(val))
# ```

# %% [markdown]
# ## Задача 21
#
# Дан код ниже, используйте правильную функцию на третьей строке для получения наименьшего ключа в словаре.
#
# ```python
# crypto = {1: "Bitcoin", 2: "Ethereum", 3: "Litecoin", 4: "Stellar", 5: "XRP"}
# key =
# print(key)
# ```

# %% [markdown]
# ## Задача 22
#
# Дан код ниже, используйте правильный метод на третьей строке для получения списка всех ключей в словаре.
#
# ```python
# crypto = {1: "Bitcoin", 2: "Ethereum", 3: "Litecoin", 4: "Stellar", 5: "XRP"}
# keys =
# print(list(keys))
# ```

# %% [markdown]
# ## Задача 23
#
# Дан код ниже, используйте правильный метод на третьей строке для возврата и удаления произвольной пары ключ-значение из словаря.
# ```python
# crypto = {1: "Bitcoin", 2: "Ethereum", 3: "Litecoin", 4: "Stellar", 5: "XRP"}
# print(len(crypto))
# ```
