# %% [markdown]
# # Модуль 3 Типы данных
# ## Задача 24
#
# Дано следующий код, используйте правильную функцию на строке 3 для преобразования value в строку.
#
# ```python
# value = 10
# conv =
# print(type(conv))
# ```

# %% [markdown]
# ## Задача 25
#
# Дано следующий код, используйте правильную функцию на строке 3 для преобразования value в целое число.
#
# ```python
# value = "10"
# conv =
# print(type(conv))
# ```

# %% [markdown]
# ## Задача 26
#
# Дано следующий код, используйте правильную функцию на строке 3 для преобразования value в число с плавающей точкой.
#
# ```python
# value = 10
# conv =
# print(type(conv))
# ```

# %% [markdown]
# ## Задача 27
#
# Дано следующий код, используйте правильную функцию на строке 3 для преобразования value в список.
#
# ```python
# value = "Hello!"
# conv =
# print(type(conv))
# ```

# %% [markdown]
# ## Задача 28
#
# Дано следующий код, используйте правильную функцию на строке 3 для преобразования value в кортеж.
#
# ```python
# value = [1, 2, 3, 10, 20, 30]
# conv =
# print(type(conv))
# ```

# %% [markdown]
# ## Задача 29
#
# Дано следующий код, используйте правильную функцию на строке 3 для преобразования value в замороженное множество.
#
# ```python
# value = (10, 20, 40, 10, 25, 30, 45)
# conv =
# print(type(conv))
# ```

# %% [markdown]
# ## Задача 30
#
# Дано следующий код, используйте правильную функцию на строке 3 для преобразования value в двоичное представление.
#
# ```python
# value = 10
# conv =
# print(conv)
# ```

# %% [markdown]
# ## Задача 31
#
# Дано следующий код, используйте правильную функцию на строке 3 для преобразования value в шестнадцатеричное представление.
#
# ```python
# value = 10
# conv =
# print(conv)
# ```

# %% [markdown]
# ## Задача 32
#
# Дано следующий код, используйте правильную функцию на строке 3 для преобразования value из двоичного в десятичное представление.
#
# ```python
# value = '0b1010'
# conv =
# print(conv)
# ```

# %% [markdown]
# ## Задача 33
#
# Дано следующий код, используйте правильную функцию на строке 3 для преобразования value из шестнадцатеричного в десятичное представление.
#
# ```python
# value = '0xa'
# conv =
# print(conv)
# ```
