# %% [markdown]
# # Модуль 4 Условия
#
# ## Задача 34
#
# Рассмотрим следующий код. Напишите код, который выводит 'True!' если строка `x` содержит 50 символов или более.
#
# ```python
# x = "The days of Python 2 are almost over. Python 3 is the king now."
# ```

# %% [markdown]
# ## Задача 35
#
# Рассмотрим следующий код. Напишите код, который выводит 'True!' если строка `x` является строкой и первый символ строки – это буква 'T'.
#
# ```python
# x = "The days of Python 2 are almost over. Python 3 is the king now."
# ```

# %% [markdown]
# ## Задача 36
#
# Рассмотрим следующий код. Напишите код, который выводит 'True!' если хотя бы одно из следующих условий выполняется:
# - строка содержит символ 'z'
# - в строке содержится символ 'y' дважды или более
#
# ```python
# x = "The days of Python 2 are almost over. Python 3 is the king now."
# ```

# %% [markdown]
# ## Задача 37
#
# Рассмотрим следующий код. Напишите код, который выводит 'True!' если индекс первого вхождения буквы 'f' меньше 10, иначе выведите 'False!'
#
# ```python
# x = "The days of Python 2 are almost over. Python 3 is the king now."
# ```

# %% [markdown]
# ## Задача 38
#
# Рассмотрим следующий код. Напишите код, который выводит 'True!' если последние три символа строки являются цифрами, иначе выведите 'False!'
# Подсказка! Используйте подходящий метод для проверки того, что указанная подстрока содержит только цифры.
#
# ```python
# x = "The days of Python 2 are almost over. Python 3 is the king now."
# ```

# %% [markdown]
# ## Задача 39
#
# Рассмотрим следующий код. Напишите код, который выводит 'True!' если строка `x` содержит не менее 8 элементов и элемент, находящийся на позиции 6, является числом с плавающей запятой, иначе выведите 'False!'
#
# ```python
# x = [115, 115.9, 116.01, ["length", "width", "height"], 109, 115, 119.5, ["length", "width", "height"]]
# ```

# %% [markdown]
# ## Задача 40
#
# Рассмотрим следующий код. Напишите код, который выводит 'True!' если вторая строка первой списка в `X` заканчивается на букву 'h', а первая строка второй списка в `x` также заканчивается на букву 'h', иначе выведите 'False!'
#
# ```python
# x = [115, 115.9, 116.01, ["length", "width", "height"], 109, 115, 119.5, ["length", "width", "height"]]
# ```

# %% [markdown]
# ## Задача 41
#
# Рассмотрим следующий код. Напишите код, который выводит 'True!' если одно из следующих двух условий выполняется иначе выведите 'False!'
# - третья строка первой списка в `x` заканчивается на букву 'h'
# - вторая строка второй списка в `x` также заканчивается на букву 'h'
#
# ```python
# x = [115, 115.9, 116.01, ["length", "width", "height"], 109, 115, 119.5, ["length", "width", "height"]]
# ```

# %% [markdown]
# ## Задача 42
#
# Рассмотрим следующий код. Напишите код, который выводит 'True!' если максимальное значение среди первых трех элементов списка меньше либо равно минимальному значению следующих трех элементов списка. В противном случае выведите 'False!'
# Подсказка! Используйте подходящие срезы для сравнения.
#
# ```python
# x = [115, 115.9, 116.01, 109, 115, 119.5, ["length", "width", "height"]]
# ```

# %% [markdown]
# ## Задача 43
#
# Рассмотрим следующий код. Напишите код, который выводит 'True!' если число `115` встречается хотя бы один раз внутри списка или оно является первым элементом в списке. В противном случае выведите 'False!'
# Подсказка! Используйте подходящий метод для проверки того, что `115` является первым элементом в списке.
#
# ```python
# x = [115, 115.9, 116.01, 109, 115, 119.5, ["length", "width", "height"]]
# ```

# %% [markdown]
# ## Задача 44
#
# Рассмотрим следующий код. Напишите код, который выводит 'True!' если значение, связанное с ключом номер 5, является Perl или количество пар ключ-значение делится на 5 с остатком меньше 2. В противном случае выведите 'False!'
#
# ```python
# x = {1: "Python", 2: "Java", 3: "Javascript", 4: "Ruby", 5: "Perl", 6: "C#", 7: "C++"}
# ```

# %% [markdown]
# ## Задача 45
#
# Рассмотрим следующий код. Напишите код, который выводит 'True!' если ключ `3` есть в словаре и минимальное значение (алфавитным порядком) в словаре является C#. В противном случае выведите 'False!'
#
# ```python
# x = {1: "Python", 2: "Java", 3: "Javascript", 4: "Ruby", 5: "Perl", 6: "C#", 7: "C++"}
# ```

# %% [markdown]
# ## Задача 46
#
# Рассмотрим следующий код. Напишите код, который выводит 'True!' если последний символ наибольшего по алфавиту значения в словаре равен 'n'. В противном случае выведите 'False!'
#
# ```python
# x = {1: "Python", 2: "Java", 3: "Javascript", 4: "Ruby", 5: "Perl", 6: "C#", 7: "C++"}
# ```

# %% [markdown]
# ## Задача 47
#
# Рассмотрим следующий код. Напишите код, который выводит 'True!' если наибольший ключ в словаре делённый на второй наибольший ключ возвращает остаток, равный наименьшему ключу в словаре. В противном случае выведите 'False!'
#
# ```python
# x = {1: "Python", 2: "Java", 3: "Javascript", 4: "Ruby", 5: "Perl", 6: "C#", 7: "C++"}
# ```

# %% [markdown]
# ## Задача 48
#
# Рассмотрим следующий код. Напишите код, который выводит 'True!' если сумма всех ключей в словаре меньше количества символов в строке, полученной путём конкатенации значений, связанных с первыми тремя ключами в словаре. В противном случае выведите 'False!'
#
# ```python
# x = {1: "Python", 2: "Java", 3: "Javascript", 4: "Ruby", 5: "Perl", 6: "C#", 7: "C++"}
# ```

# %% [markdown]
# ## Задача 49
#
# Рассмотрим следующий код. Напишите код, который выводит 'True!' если третье значение первого диапазона меньше 2, выведите 'False!' если пятое значение первого диапазона равно 5, иначе выведите 'None!'
#
# ```python
# x = [list(range(5)), list(range(5,9)), list(range(1,10,3))]
# ```

# %% [markdown]
# ## Задача 50
#
# Рассмотрим следующий код. Напишите код, который выводит 'True!' если третье значение третьего диапазона меньше 6, выведите 'False!' если первый элемент второго диапазона равен 5, иначе выведите 'None!'
#
# ```python
# x = [list(range(5)), list(range(5,9)), list(range(1,10,3))]
# ```

# %% [markdown]
# ## Задача 51
#
# Рассмотрим следующий код. Напишите код, который выводит 'True!' если последнее значение первого диапазона больше 3, выведите 'False!' если последнее значение второго диапазона меньше 9, иначе выведите 'None!'
#
# ```python
# x = [list(range(5)), list(range(5,9)), list(range(1,10,3))]
# ```

# %% [markdown]
# ## Задача 52
#
# Рассмотрим следующий код. Напишите код, который выводит 'True!' если длина первого диапазона больше или равна 5, выведите 'False!' если длина второго диапазона равна 4, иначе выведите 'None!'
#
# ```python
# x = [list(range(5)), list(range(5,9)), list(range(1,10,3))]
# ```

# %% [markdown]
# ## Задача 53
#
# Рассмотрим следующий код. Напишите код, который выводит 'True!' если сумма всех элементов первого диапазона больше суммы всех элементов третьего диапазона, выведите 'False!' если наибольший элемент второго диапазона больше наибольшего элемента третьего диапазона, иначе выведите 'None!'
#
# ```python
# x = [list(range(5)), list(range(5,9)), list(range(1,10,3))]
# ```

# %% [markdown]
# ## Задача 54
#
# Рассмотрим следующий код. Напишите код, который выводит 'True!' если наибольший элемент первого диапазона минус второй элемент третьего диапазона равен первому элементу первого диапазона, выведите 'False!' если длина первого диапазона минус длина второго диапазона равен первому элементу третьего диапазона, выведите 'Maybe!' если сумма всех элементов третьего диапазона деленная пополам возвращает остаток 0, иначе выведите 'None!'
#
# ```python
# x = [list(range(5)), list(range(5,9)), list(range(1,10,3))]
# ```

# %% [markdown]
# ## Задача 55
#
# Рассмотрим следующий код. Напишите код, который выводит 'True!' если сумма последних трех элементов первого диапазона плюс сумма последних трех элементов третьего диапазона равен сумме последних трех элементов второго диапазона, иначе выведите 'False!' если длина первого диапазона умноженная на 2 меньше суммы всех элементов третьего диапазона.
#
# ```python
# x = [list(range(5)), list(range(5,9)), list(range(1,10,3))]
# ```

# %% [markdown]
# ## Задача 56
#
# Рассмотрим следующий код. Напишите код, который выводит 'True!' если вторая буква значения по ключу 1 присутствует в значении по ключу 4, иначе выведите 'False!'
#
# ```python
# x = {1: "Python", 2: "Java", 3: "Javascript", 4: "Ruby", 5: "Perl", 6: "C#", 7: "C++"}
# ```

# %% [markdown]
# ## Задача 57
#
# Рассмотрим следующий код. Напишите код, который выводит 'True!' если предпоследняя буква значения по ключу 3 равна первой букве значения по ключу 5, иначе выведите 'False!'
#
# ```python
# x = {1: "Python", 2: "Java", 3: "Javascript", 4: "Ruby", 5: "Perl", 6: "C#", 7: "C++"}
# ```

# %% [markdown]
# ## Задача 58
#
# Рассмотрим следующий код. Напишите код, который выводит 'True!' если количество символов в минимальном значении в словаре равно количеству вхождений буквы 'a' в значении по ключу 3, иначе выведите 'False!'
#
# ```python
# x = {1: "Python", 2: "Java", 3: "Javascript", 4: "Ruby", 5: "Perl", 6: "C#", 7: "C++"}
# ```
