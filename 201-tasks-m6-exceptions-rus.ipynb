# %% [markdown]
# # Модуль 6 Исключения
#
# ## Задача 84
#
# Исправьте код ниже так, чтобы он не вызывал ошибку SyntaxError. Подсказка! Результат должен быть 20 200
#
# ```python
# x = [1, 2]
# y = [10, 100]
#
# for i in x:
# for j in y:
# if i % 2 == 0
# print(i * j)
# ```

# %% [markdown]
# ## Задача 85
#
# Исправьте код ниже так, чтобы он не вызывал ошибку TypeError. Подсказка! Результат должен быть 20 200
#
# ```python
# x = [1, 2]
# y = [10, 100]
# for i in x:
# for j in y:
# if y % 2 == 0:
# print(i * j)
# ```

# %% [markdown]
# ## Задача 86
#
# Исправьте код ниже так, чтобы он не вызывал ошибку IndexError. Подсказка! Результат должен быть 200 200
#
# ```python
# x = [1, 2]
# y = [10, 100]
# for i in x:
# for j in y:
# if i % 2 == 0:
# print(x[1] * y[2]))
# ```

# %% [markdown]
# ## Задача 87
#
# Добавьте необходимые конструкции к коду ниже так, чтобы в случае возникновения исключения ZeroDivisionError программа выводила на экран строку "Zero!".
#
# ```python
# try:
# print(25 % 0)
# ```

# %% [markdown]
# ## Задача 88
#
# Добавьте необходимые конструкции к коду ниже так, чтобы в случае выполнения кода под блоком `try` без исключений программа вывела результат математической операции и строку "Clean!" на экран.
#
# ```python
# try:
# print(25 % 5 ** 5 + 5)
# except:
# print("Bug!")
# ```

# %% [markdown]
# ## Задача 89
#
# Добавьте необходимые конструкции к коду ниже так, чтобы при любом исключении программа всегда выводила строку "Result!" на экран.
#
# ```python
# try:
# print(25 % 0 ** 5 + 5)
# except:
# print("Bug!")
# ```

# %% [markdown]
# ## Задача 90
#
# Добавьте необходимые конструкции к коду ниже так, чтобы в случае возникновения исключения ZeroDivisionError программа выводила строку "Zero!", а если возникает исключение IndexError, то выводилась строка "Index!".
#
# ```python
# x = [1, 9, 17, 32]
# try:
# print(x[3] % 3 ** 5 + x[4])
# ```

# %% [markdown]
# ## Задача 91
#
# Добавьте необходимые конструкции к коду ниже так, чтобы в случае выполнения кода под блоком `try` без исключений программа вывела результат математической операции и строку "Clean!". В случае возникновения исключения ZeroDivisionError программа должна выводить строку "Zero!". Независимо от результата, программа всегда выводит строку "Finish!".
#
# ```python
# try:
# print(25 % 5 ** 5 + 5)
# ```
