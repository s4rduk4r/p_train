# %% [markdown]
# # Модуль 7 Функции
#
# ## Задача 93
#
# Реализуйте функцию под названием `my_func()`, которая просто выведет на экран текст "Hello Python!" и затем вызовите эту функцию.

# %% [markdown]
# ## Задача 94
#
# Реализуйте функцию под названием `my_func()`, которая создаст переменную `add` и сохранит в ней результат сложения чисел 10 и 20, а также выведет значение этой переменной на экран. Не забудьте также вызвать эту функцию!

# %% [markdown]
# ## Задача 95
#
# Реализуйте функцию под названием `my_func()`, которая принимает один параметр `x` и умножает его на 10, а также возвращает результат при вызове функции.
#
# ```python
# result = my_func(7)
# print(result)
# ```

# %% [markdown]
# ## Задача 96
#
# Реализуйте функцию под названием `my_func()`, которая принимает два параметра `x` и `y` и делит `x` на `y`, а также возвращает результат при вызове функции.
#
# ```python
# result = my_func(38,19)
# print(result)
# ```

# %% [markdown]
# ## Задача 97
#
# Реализуйте функцию под названием `my_func()`, которая принимает три параметра `x`, `y` и `z`, возносит `x` в степень `y`, затем добавляет `z` к этому значению, а также возвращает результат при вызове функции.
#
# ```python
# result = my_func(3,3,3)
# print(result)
# ```

# %% [markdown]
# ## Задача 98
#
# Реализуйте функцию под названием `my_func()`, которая принимает один параметр `x` и умножает его на каждый элемент в диапазоне от 0 до 4, добавляя каждое произведение в новый пустой список `my_new_list`. Наконец, выведите этот список на экран после вызова функции.
#
# ```python
# result = my_func(2)
# print(result)
# ```

# %% [markdown]
# ## Задача 99
#
# Реализуйте функцию под названием `my_func()`, которая принимает один параметр `x` (строку) и переводит все символы строки в верхний регистр, а также возвращает результат при вызове функции.
#
# ```python
# result = my_func("Edcorner Learning”)
# print(result)
# ```

# %% [markdown]
# ## Задача 100
#
# Реализуйте функцию под названием `my_func()`, которая принимает один параметр `x` (список) и удаляет из него все дубликаты, а также возвращает результат при вызове функции.
#
# ```python
# result = my_func([11, 12, 13, 11, 15, 18, 18, 22, 20, 16, 12])
# print(result)
# ```

# %% [markdown]
# ## Задача 101
#
# Реализуйте функцию под названием `my_func()`, которая принимает один параметр `x` (кортеж) и для каждого элемента этого кортежа, который больше 4, возводит этот элемент в степень 2, а также добавляет его к новому пустому списку `my_newlist`. Наконец, функция возвращает результат при её вызове.
#
# ```python
# result = my_func((2, 3, 5, 6, 4, 8, 9))
# print(result)
# ```

# %% [markdown]
# ## Задача 102
#
# Реализуйте функцию под названием `my_func()`, которая принимает один параметр `x` (словарь) и умножает количество элементов в этом словаре на значение самого большого ключа в словаре, а также возвращает результат при вызове функции.
#
# ```python
# result = my_func({1: 3, 2: 3, 4: 5, 5: 9, 6: 8, 3: 7, 7: 0})
# print(result)
# ```

# %% [markdown]
# ## Задача 103
#
# Реализуйте функцию под названием `my_func()`, которая принимает один позиционный параметр `x` и параметр по умолчанию `y`, равный 10, умножает эти два значения и возвращает результат при вызове функции.
#
# ```python
# result = my_func(5)
# print(result)
# ```

# %% [markdown]
# ## Задача 104
#
# Реализуйте функцию под названием `my_func()`, которая принимает один позиционный параметр `x` и два параметра по умолчанию `y` и `z`, равные 100 и 200 соответственно, складывает их вместе и возвращает результат при вызове функции.
#
# ```python
# result = my_func(50)
# print(result)
# ```

# %% [markdown]
# ## Задача 105
#
# Реализуйте функцию под названием `my_func()`, которая принимает один позиционный параметр `x` и один параметр по умолчанию `y`, равный индексу в списке, и возвращает элемент списка `x` с индексом `y`, а также выводит результат на экран при вызове функции.
#
# ```python
# result = my_func(list(range(2,25,2)), 4)
# print(result) # результат должен быть 10
# ```

# %% [markdown]
# ## Задача 106
#
# Реализуйте функцию под названием `my_func()`, которая принимает один позиционный параметр `x` и переменное количество дополнительных позиционных параметров, и возвращает результат умножения `x` на второй параметр, а также возвращает результат при вызове функции.
#
# ```python
# result = my_func(5, 10, 20, 30, 50)
# print(result)
# ```

# %% [markdown]
# ## Задача 107
#
# Реализуйте функцию под названием `my_func()`, которая принимает один позиционный параметр `x` и переменное количество дополнительных параметров типа ключ-значение, и возвращает результат умножения `x` на самую большую из этих значений, а также возвращает результат при вызове функции.
#
# ```python
# result = my_func(10, val1 = 10, val2 = 15, val3 = 20, val4 = 25, val5 = 30)
# print(result)
# ```

# %% [markdown]
# ## Задача 108
#
# Добавьте правильный код внутри функции, чтобы получить результат 200 при вызове функции `myfunc()` и вывести его на экран.
#
# ```python
# var = 10
# def my_func(x):
# my_func(20)
# ```

# %% [markdown]
# ## Задача 109
#
# Добавьте правильный код внутри функции, чтобы получить результат 100 при вызове функции `myfunc()` и вывести его на экран.
#
# ```python
# var = 10
# def my_func(x):
# print(x * var)
# my_func(20)
# ```

# %% [markdown]
# ## Задача 110
#
# Внесите необходимые изменения внутри функции, чтобы получить результат 120 при вызове функции `myfunc()` и вывести его на экран.
#
# ```python
# def my_func(x):
# print(x * var)
# var = 12
# my_func(10)
# ```

# %% [markdown]
# ## Задача 111
#
# Внесите необходимый код внутри функции, чтобы получить результат 80 при вызове функции `myfunc()` и вывести его на экран.
#
# ```python
# var = 8
# def my_func(x):
# print(x * var)
# var = 12
# my_func(10)
# ```

# %% [markdown]
# ## Задача 112
#
# Импортируйте только переменную `pi` из модуля `math` и затем форматируйте ее так, чтобы у нее было четыре знака после запятой. Разумеется, выведите результат на экран с помощью функции `print()`.

# %% [markdown]
# ## Задача 113
#
# Добавьте необходимый код внутри функции в скобки `print()`, чтобы прочитать содержимое файла `test.txt` как строку и вывести его на экран.
#
# ```python
# f = open("test.txt", "r")
# print()
# ```

# %% [markdown]
# ## Задача 114
#
# Добавьте необходимый код внутри функции в скобки `print()`, чтобы прочитать содержимое файла `test.txt` как список строк, где каждая строка является элементом списка, и вывести его на экран.
#
# ```python
# f = open("test.txt", "r")
# print()
# ```

# %% [markdown]
# ## Задача 115
#
# Добавьте необходимый код на пятом строчке, чтобы переместить курсор обратно в начало файла `test.txt` перед чтением из файла снова.
#
# ```python
# f = open("test.txt", "r")
# f.read()
# print(f.read())
# ```

# %% [markdown]
# ## Задача 116
#
# Добавьте необходимый код на пятом строчке (внутри скобок `print()`) для получения текущего положения курсора внутри файла `test.txt` и вывести это на экран.
#
# ```python
# f = open("test.txt", "r")
# f.read(5)
# print()
# ```

# %% [markdown]
# ## Задача 117
#
# Добавьте необходимый код на пятом строчке (внутри скобок `print()`) для получения текущего режима открытия файла `test.txt` (read, write и т.д.) и вывести это на экран.
#
# ```python
# f = open("test.txt", "r")
# f.read(5)
# print()
# ```

# %% [markdown]
# ## Задача 118
#
# Добавьте необходимый режим доступа на первой строке для открытия файла `test.txt` для дописывания и чтения одновременно.
#
# ```python
# f = open("test.txt", )
# print(f.mode)
# ```

# %% [markdown]
# ## Задача 119
#
# Добавьте необходимый код на третьей и четвертой строках для записи строки `python` в файл `test.txt` и вывести результат чтения файла на экран.
#
# ```python
# f = open("test.txt", "w")
# f = open("test.txt", "r")
# print(f.read())
# ```

# %% [markdown]
# ## Задача 120
#
# Добавьте необходимый код на третьей и четвертой строках для записи списка строк `['python', ' ', 'and', ' 'java']` в файл `test.txt` и вывести результат чтения файла на экран.
#
# ```python
# f = open("test.txt", "w")
# f = open("test.txt", "r")
# print(f.read())
# ```

# %% [markdown]
# ## Задача 121
#
# Начните код с первой строки для записи строки `python` и закрыть файл `test.txt` правильно с использованием конструкции `with`.
#
# ```python
# f = open("test.txt", "r")
# print(f.read())
# ```

# %% [markdown]
# ## Задача 122
#
# Добавьте необходимый код на третьей и четвертой строках для удаления всего содержимого файла `test.txt`.
#
# ```python
# with open("test.txt", "w") as f:
#     f.write("python")
# f = open("test.txt", "r")
# print(f.read())
# ```
