# %% [markdown]
# # Модуль 8 Регулярные выражения
#
# ## Задача 123
#
# Напишите код на строке 5, чтобы найти слово Python в начале строки с помощью метода match().
#
# ```python
# import re
# s = " Python exercises consist of various Modules
# result =
# print(result.group())
# ```

# %% [markdown]
# ## Задача 124
#
# Напишите код на строке 5, чтобы найти слово Bitcoin в начале строки, игнорируя регистр с помощью метода match(). Таким образом, неважно, будете ли вы использовать bitcoin или Bitcoin, результат будет одинаковый.
#
# ```python
# import re
# s = "Bitcoin was born on Jan 3rd 2009 as an alternative to the failure of the current ﬁnancial system. In 2017, the price of 1 BTC reached $20000, with a market cap of over $300B."
#
# print(result.group())
# ```

# %% [markdown]
# ## Задача 125
#
# Напишите код на строке 5, чтобы найти слово Bitcoin в начале строки с помощью метода match(). Используйте точку (.) из синтаксиса регулярных выражений в вашем решении.
#
# ```python
# import re
# s = "Bitcoin was born on Jan 3rd 2009 as an alternative to the
# failure of the current ﬁnancial system. In 2017, the price of 1 BTC
# reached $20000, with a market cap of over $300B."
# result =
# print(result.group())
# ```

# %% [markdown]
# ## Задача 126
#
# Напишите код на строке 5, чтобы найти год 2009 в строке с помощью метода search(). Используйте символ \d в вашем решении.
#
# ```python
# import re
# s = "Bitcoin was born on Jan 3rd 2009 as an alternative to the failure
# of the current ﬁnancial system. In 2017, the price of 1 BTC reached
# $20000, with a market cap of over $300B."
# result =
# print(result.group(1))
# ```
