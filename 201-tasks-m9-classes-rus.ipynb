# %% [markdown]
# # Модуль 9 Классы
#
# ## Задача 127
#
# Напишите класс под названием `ClassOne`, начиная с первой строки содержащий:
# - Метод `__init__` с двумя параметрами `p1` и `p2`. Определите соответствующие атрибуты внутри метода `__init__`.
# - Метод под названием `square`, который принимает один параметр `p3` и выводит значение квадрата `p3`.
#
# ```python
# class
# p = ClassOne(1, 2)
# print(type(p))
# ```

# %% [markdown]
# ## Задача 128
#
# С учетом класса `ClassOne` и объекта `p`, напишите код на 11 строке для доступа к атрибуту `p1` текущего экземпляра класса и выведите его значение на экран.
#
#
# ```python
# class ClassOne(object):
#     def __init__(self, p1, p2):
#         self.p1 = p1
#         self.p2 = p2
#     def square(self, p3):
#         print(p3 ** 2)
# p = ClassOne(1, 2)
# ```

# %% [markdown]
# ## Задача 129
#
# С учетом класса `ClassOne` и объекта `p`, напишите код на 11 строке для вызова метода `square()` для текущего экземпляра класса с аргументом 10 и выведите результат на экран.
#
#
# ```python
# class ClassOne(object):
#     def __init__(self, p1, p2):
#         self.p1 = p1
#         self.p2 = p2
#     def square(self, p3):
#         print(p3 ** 2)
# p = ClassOne(1, 2)
# ```

# %% [markdown]
# ## Задача 130
#
# С учетом класса `ClassOne` и объекта `p`, напишите код на 11 строке для установки значения атрибута `p2` равным 5 для текущего экземпляра класса без использования функции.
#
#
# ```python
# class ClassOne(object):
#     def __init__(self, p1, p2):
#         self.p1 = p1
#         self.p2 = p2
#     def square(self, p3):
#         print(p3 ** 2)
# p = ClassOne(1, 2)
# print(p.p2)
# ```

# %% [markdown]
# ## Задача 131
#
# С учетом класса `ClassOne` и объекта `p`, напишите код на 11 и 12 строках для установки значения атрибута `p2` равным 50 для текущего экземпляра класса используя функцию, затем получите новое значение `p2`, также используя функцию, и выведите его на экран.
#
#
# ```python
# class ClassOne(object):
#     def __init__(self, p1, p2):
#         self.p1 = p1
#         self.p2 = p2
#     def square(self, p3):
#         print(p3 ** 2)
# p = ClassOne(1, 2)
# ```

# %% [markdown]
# ## Задача 132
#
# С учетом класса `ClassOne` и объекта `p`, напишите код для проверки наличия атрибута `p2` у объекта `p`, используя функцию, а также выведите результат на экран.
#
#
# ```python
# class ClassOne(object):
#     def __init__(self, p1, p2):
#         self.p1 = p1
#         self.p2 = p2
#     def square(self, p3):
#         print(p3 ** 2)
# p = ClassOne(1, 2)
# ```

# %% [markdown]
# ## Задача 133
#
# С учетом класса `ClassOne` и объекта `p`, напишите код для проверки является ли объект `p` экземпляром класса `ClassOne`, используя функцию, а также выведите результат на экран.
#
# ```python
# class ClassOne(object):
#     def __init__(self, p1, p2):
#         self.p1 = p1
#         self.p2 = p2
#     def square(self, p3):
#         print(p3 ** 2)
# p = ClassOne(1, 2)
# ```

# %% [markdown]
# ## Задача 134
#
# С учетом класса `ClassOne`, напишите код начиная с 9 строки для создания дочернего класса под названием `ClassTwo`, который наследуется от `ClassOne` и имеет свой собственный метод `times10()`, который принимает один параметр `x` и выводит результат умножения `x` на 10.
#
# ```python
# class ClassOne(object):
#     def __init__(self, p1, p2):
#         self.p1 = p1
#         self.p2 = p2
#     def square(self, p3):
#         print(p3 ** 2)
# ```

# %% [markdown]
# ## Задача 135
#
# С учетом классов `ClassOne` и `ClassTwo`, где последний является потомком первого, напишите код на 15 строке для вызова метода `times10()` из дочернего класса при условии что `x` равно 45, также выведите результат на экран.
#
# ```python
# class ClassOne(object):
# def __init__(self, p1, p2):
# self.p1 = p1
# self.p2 = p2
# def square(self, p3):
# print(p3 ** 2)
# class ClassTwo(ClassOne):
# def times10(self, x):
# return x * 10
# obj = ClassTwo(15, 25)
# ```

# %% [markdown]
# ## Задача 136
#
# С учетом классов `ClassOne` и `ClassTwo`, напишите код на 13 строке для проверки того, является ли `ClassTwo` действительно потомком `ClassOne`, также выведите результат на экран.
#
#
# ```python
# class ClassOne(object):
# def __init__(self, p1, p2):
# self.p1 = p1
# self.p2 = p2
# def square(self, p3):
# print(p3 ** 2)
# class ClassTwo(ClassOne):
# def times10(self, x):
# return x * 10
# ```
